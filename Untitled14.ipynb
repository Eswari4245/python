# %%
l = [1,2,3,4]
print(l)
print(type(l))
# Out:
# [1, 2, 3, 4]
# <class 'list'>

# %%
Eshuu = [1,2,3,4]
print(l)
print(type(l))
# Out:
# [1, 2, 3, 4]
# <class 'list'>

# %%
a = [1,2,3,4]
print(l)
print(a[1])
# Out:
# [1, 2, 3, 4]
# 2

# %%
a = [1,2,3,4]
print(a[1] * a[3])
# Out:
# 8

# %%
my_list = [1,12.2,'hello',57.2,'123','true',795]
print(my_list[2])
print(type(my_list[2]))
# Out:
# hello
# <class 'str'>

# %%
x = {10,20,30}
print(x)
print(type(x))
# Out:
# {10, 20, 30}
# <class 'set'>

# %%
x = (10,20,30)
print(x)
print(type(x))
# Out:
# (10, 20, 30)
# <class 'tuple'>

# %%
x = (10,20,30)
print(x[0])
# Out:
# 10

# %%
x = [10,20,30]
print(x)
print(type(x))
# Out:
# [10, 20, 30]
# <class 'list'>

# %%
my_set = {'a','a','a','a'}
print(my_set)
# Out:
# {'a'}

# %%
f = ('a','b','c','d')
print(f)
# Out:
# ('a', 'b', 'c', 'd')

# %%
a1 = {10,20,30}
a2 = {30,40,50,10}
print(a1.intersection(a2))
# Out:
# {10, 30}

# %%
a1 = {10,20,30}
a2 = {30,40,50,10}
print(a1.union(a2))
# Out:
# {50, 20, 40, 10, 30}

# %%
d = {'uma':20,
     'akhil':50,
     'teju':70,
     'lihiha':90,
     'eshuu':0}
print(d)
print(type(d))
# Out:
# {'uma': 20, 'akhil': 50, 'teju': 70, 'lihiha': 90, 'eshuu': 0}
# <class 'dict'>

# %%
a = 11
b = 15
print(a*b)
# Out:
# 165
